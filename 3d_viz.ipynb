# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-rajk/random_colab/blob/main/3d_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# Load your data
df = pd.read_csv('/content/Ghy_avg_temp_51yrs - ghy_date_avg_73-23.csv')



# Remove February 29th from the dataset
df = df[~df['datetime'].str.contains('29-02')]

# Interpolate missing values
df.interpolate(method='linear', inplace=True, axis=0)

# Convert the 'datetime' column to a numerical format for plotting
df['datetime'] = pd.to_datetime(df['datetime'], format='%d-%m').dt.dayofyear

# Prepare the data for Plotly
X = df['datetime'].values
Y = np.array(df.columns[1:], dtype=int)
Z = df.iloc[:, 1:].values
# Out:
# <ipython-input-3-c7e9b15495c3>:10: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear', inplace=True, axis=0)

# %%
# Create a 3D surface plot
fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y, colorscale='Viridis')])

# Add title and labels
fig.update_layout(title='3D Plot of Average Temperature Across 51 Years',
                  scene=dict(xaxis_title='Date (Day of Year)',
                             yaxis_title='Year',
                             zaxis_title='Average Temperature (°C)'),
                  autosize=True,
                  width=800, height=800)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
